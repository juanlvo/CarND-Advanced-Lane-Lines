# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
# %matplotlib inline

# Read in a calibration image
#
images = glob.glob('camera_cal/calibration*.jpg')

#plt.imshow(images)

# Arrays to store object points and image points from all the images

objpoints = [] #3D points in real world space
imgpoints = [] #2D points in image plane

# Prepare object points like (0,0,0), (1,0,0), (2,0,0), ..., (7,5,0)
objp = np.zeros((6*8,3), np.float32)
objp[:,:2] = np.mgrid[0:8,0:6].T.reshape(-1,2) #x,y coordinates

for fname in images:
    img = mpimg.imread(fname)
    # Convert the image in grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

    # Find the cheesboard corners
    ret, corners = cv2.findChessboardCorners(gray, (9,6),None)

    # If corners are found, add object points, image points
    if ret == True:
        imgpoints.append(corners)
        objpoints.append(objp)

        # draw and display the corners
        img = cv2.drawChessboardCorners(img, (9,6), corners, ret)
        plt.figure()
        plt.imshow(img)
    else :
        print(fname)

ret, mtx, dist, rvecs, tvecvs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)
dst = cv2.undistort(img, mtx, dist, None, mtx)
# Out:
# camera_cal/calibration5.jpg
# camera_cal/calibration1.jpg
# camera_cal/calibration4.jpg

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib qt

# read and display the original image
img = mpimg.imread('test_images/test1.jpg')
#plt.figure()
plt.imshow(img)
plt.plot(300, 674, '.') #bottom left
plt.plot(1068, 674, '.') #bottom right
plt.plot(355, 639, '.') #top right
plt.plot(1028, 639, '.') #top left
# Out:
#   File "<ipython-input-1-f19842ca02db>", line 9
#     (/plt.figure())
#      ^
# SyntaxError: invalid syntax
